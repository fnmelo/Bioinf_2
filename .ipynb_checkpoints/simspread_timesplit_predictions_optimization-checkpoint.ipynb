# %%
using DataFrames
using CSV
using Glob
using Chain
using Statistics
using SimSpread
using ArgParse
using Base.Threads
using MLBase
using ProgressMeter
using AlgebraOfGraphics
using CairoMakie
using Plots
using StatsPlots
include("getmetrics.jl")
# Out:
# ┌ Warning: The NVIDIA driver on this system only supports up to CUDA 11.0.0.
# │ For performance reasons, it is recommended to upgrade to a driver that supports CUDA 11.2 or higher.
# └ @ CUDA ~/.julia/packages/CUDA/is36v/src/initialization.jl:70
# ["/CLUSTERFS/homes/fnmelo/.local/share/jupyter/runtime/kernel-02c129a9-2d2e-4b26-b065-86a7621977da.json"]
# LoadError: ArgParseError("too many arguments")
# in expression starting at /CLUSTERFS/homes/fnmelo/Bioinf_2/getmetrics.jl:200
#
# Stacktrace:
#   [1] argparse_error(x::Any)
#     @ ArgParse ~/.julia/packages/ArgParse/bylyV/src/parsing.jl:9
#   [2] parse_arg!(state::ArgParse.ParserState, settings::ArgParseSettings)
#     @ ArgParse ~/.julia/packages/ArgParse/bylyV/src/parsing.jl:918
#   [3] parse_args_unhandled(args_list::Vector, settings::ArgParseSettings, truncated_shopts::Bool)
#     @ ArgParse ~/.julia/packages/ArgParse/bylyV/src/parsing.jl:632
#   [4] parse_args_unhandled(args_list::Vector, settings::ArgParseSettings)
#     @ ArgParse ~/.julia/packages/ArgParse/bylyV/src/parsing.jl:595
#   [5] parse_args(args_list::Vector, settings::ArgParseSettings; as_symbols::Bool)
#     @ ArgParse ~/.julia/packages/ArgParse/bylyV/src/parsing.jl:469
#   [6] parse_args(args_list::Vector, settings::ArgParseSettings)
#     @ ArgParse ~/.julia/packages/ArgParse/bylyV/src/parsing.jl:465
#   [7] main(args::Vector{String})
#     @ Main /CLUSTERFS/homes/fnmelo/Bioinf_2/getmetrics.jl:158
#   [8] top-level scope
#     @ /CLUSTERFS/homes/fnmelo/Bioinf_2/getmetrics.jl:200
#   [9] include(fname::String)
#     @ Base.MainInclude ./client.jl:476
#  [10] top-level scope
#     @ In[1]:15

# %%
path = "/CLUSTERFS/homes/fnmelo/Bioinf_2"
files = glob("*.out", path)
df = DataFrame()


for file in files
    # extract
    α = @chain file begin
        basename
        replace(".out" => "")
        split('.')
        last
        split('_')
        last
    end
    
    α_value = if startswith(α, "00")
              parse(Float64, α, ) / 100
          else
              parse(Float64, α) / 10
          end
 
    
    # file to df
    file_df = CSV.File(file, delim=",", header=["Fold", "Ligando", "Target", "Score", "TP"]) |> DataFrame
    
    # add alpha 
    file_df[!, "Alpha"] .= α_value
    
    append!(df, file_df)
end

# %%
rescore(df, mean)
# Out:
# 190785×6 DataFrame
#     Row │ Fold   Ligando      Target          TP       0.2         mean        ⋯
#         │ Int64  String15     String15        Float64  Float64?    Float64?    ⋯
# ────────┼───────────────────────────────────────────────────────────────────────
#       1 │     1   CHEMBL1062   CHEMBL1075132      0.0  0.0         4.94711e-6  ⋯
#       2 │     1   CHEMBL1062   CHEMBL1075145      0.0  0.0         6.18897e-7
#       3 │     1   CHEMBL1062   CHEMBL1075165      0.0  0.0         2.61921e-6
#       4 │     1   CHEMBL1062   CHEMBL1075323      0.0  0.0         1.30208e-6
#       5 │     1   CHEMBL1062   CHEMBL1163125      0.0  0.0         5.68893e-6  ⋯
#       6 │     1   CHEMBL1062   CHEMBL1250378      0.0  0.0         3.44353e-6
#       7 │     1   CHEMBL1062   CHEMBL1293224      0.0  0.0         2.32767e-6
#       8 │     1   CHEMBL1062   CHEMBL1293226      0.0  0.0         6.49063e-6
#       9 │     1   CHEMBL1062   CHEMBL1293267      0.0  0.0         4.11327e-6  ⋯
#      10 │     1   CHEMBL1062   CHEMBL1293289      0.0  0.0         1.08029e-6
#      11 │     1   CHEMBL1062   CHEMBL1743126      0.0  0.00195495  0.000201861
#    ⋮    │   ⋮         ⋮             ⋮            ⋮         ⋮            ⋮      ⋱
#  190776 │   483   CHEMBL99     CHEMBL5838         0.0  0.0         2.77293e-6
#  190777 │   483   CHEMBL99     CHEMBL5843         0.0  0.0         9.71593e-7  ⋯
#  190778 │   483   CHEMBL99     CHEMBL5936         0.0  0.0         2.49165e-6
#  190779 │   483   CHEMBL99     CHEMBL5971         0.0  0.0         6.37899e-6
#  190780 │   483   CHEMBL99     CHEMBL5983         0.0  2.50376e-5  1.27712e-5
#  190781 │   483   CHEMBL99     CHEMBL6002         0.0  0.0         1.47372e-5  ⋯
#  190782 │   483   CHEMBL99     CHEMBL6113         0.0  0.0         1.01789e-6
#  190783 │   483   CHEMBL99     CHEMBL6154         0.0  0.0         3.26777e-6
#  190784 │   483   CHEMBL99     CHEMBL6164         0.0  0.0         4.73767e-6
#  190785 │   483   CHEMBL99     CHEMBL6174         0.0  0.0         1.23877e-6  ⋯
#                                                             190764 rows omitted

# %%
fxs = [mean, maximum, sum]
# Out:
# 3-element Vector{Function}:
#  mean (generic function with 117 methods)
#  maximum (generic function with 104 methods)
#  sum (generic function with 31 methods)

# %%
df_2 = rescore(df, fxs)
# Out:
# 190785×8 DataFrame
#     Row │ Fold   Ligando      Target          TP       0.2         mean        ⋯
#         │ Int64  String15     String15        Float64  Float64?    Float64?    ⋯
# ────────┼───────────────────────────────────────────────────────────────────────
#       1 │     1   CHEMBL1062   CHEMBL1075132      0.0  0.0         4.94711e-6  ⋯
#       2 │     1   CHEMBL1062   CHEMBL1075145      0.0  0.0         6.18897e-7
#       3 │     1   CHEMBL1062   CHEMBL1075165      0.0  0.0         2.61921e-6
#       4 │     1   CHEMBL1062   CHEMBL1075323      0.0  0.0         1.30208e-6
#       5 │     1   CHEMBL1062   CHEMBL1163125      0.0  0.0         5.68893e-6  ⋯
#       6 │     1   CHEMBL1062   CHEMBL1250378      0.0  0.0         3.44353e-6
#       7 │     1   CHEMBL1062   CHEMBL1293224      0.0  0.0         2.32767e-6
#       8 │     1   CHEMBL1062   CHEMBL1293226      0.0  0.0         6.49063e-6
#       9 │     1   CHEMBL1062   CHEMBL1293267      0.0  0.0         4.11327e-6  ⋯
#      10 │     1   CHEMBL1062   CHEMBL1293289      0.0  0.0         1.08029e-6
#      11 │     1   CHEMBL1062   CHEMBL1743126      0.0  0.00195495  0.000201861
#    ⋮    │   ⋮         ⋮             ⋮            ⋮         ⋮            ⋮      ⋱
#  190776 │   483   CHEMBL99     CHEMBL5838         0.0  0.0         2.77293e-6
#  190777 │   483   CHEMBL99     CHEMBL5843         0.0  0.0         9.71593e-7  ⋯
#  190778 │   483   CHEMBL99     CHEMBL5936         0.0  0.0         2.49165e-6
#  190779 │   483   CHEMBL99     CHEMBL5971         0.0  0.0         6.37899e-6
#  190780 │   483   CHEMBL99     CHEMBL5983         0.0  2.50376e-5  1.27712e-5
#  190781 │   483   CHEMBL99     CHEMBL6002         0.0  0.0         1.47372e-5  ⋯
#  190782 │   483   CHEMBL99     CHEMBL6113         0.0  0.0         1.01789e-6
#  190783 │   483   CHEMBL99     CHEMBL6154         0.0  0.0         3.26777e-6
#  190784 │   483   CHEMBL99     CHEMBL6164         0.0  0.0         4.73767e-6
#  190785 │   483   CHEMBL99     CHEMBL6174         0.0  0.0         1.23877e-6  ⋯
#                                                2 columns and 190764 rows omitted

# %%
df_p = evaluate(df_2, fxs)
# Out:
# 4×10 DataFrame
#  Row │ groupid  AuROC     AuPRC     BEDROC    r20       p20        f1        b ⋯
#      │ String   Float64   Float64   Float64   Float64   Float64    Float64   F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ mean     0.788326  0.176055  0.491086  0.542592  0.0667702  0.297174  0 ⋯
#    2 │ maximum  0.794083  0.183345  0.49976   0.545372  0.0668737  0.298799  0
#    3 │ sum      0.788326  0.176055  0.491086  0.542592  0.0667702  0.297174  0
#    4 │ 0.2      0.783286  0.13993   0.473685  0.517002  0.0628364  0.229549  0
#                                                                3 columns omitted

# %%
plotmetrics(df_p)
# Out:
# (9×5 DataFrame
#  Row │ metric  mean         maximum      sum          0.2
#      │ String  Float64?     Float64?     Float64?     Float64?
# ─────┼────────────────────────────────────────────────────────────
#    1 │ AuROC     0.788326     0.794083     0.788326     0.783286
#    2 │ AuPRC     0.176055     0.183345     0.176055     0.13993
#    3 │ BEDROC    0.491086     0.49976      0.491086     0.473685
#    4 │ r20       0.542592     0.545372     0.542592     0.517002
#    5 │ p20       0.0667702    0.0668737    0.0667702    0.0628364
#    6 │ f1        0.297174     0.298799     0.297174     0.229549
#    7 │ bacc      0.750061     0.759519     0.750061     0.750781
#    8 │ acc       0.993862     0.993946     0.993862     0.993846
#    9 │ mcc     NaN          NaN          NaN          NaN, 9×5 DataFrame
#  Row │ metric  mean           maximum        sum            0.2
#      │ String  Float64?       Float64?       Float64?       Float64?
# ─────┼───────────────────────────────────────────────────────────────
#    1 │ AuROC     0.0064345      0.0137839      0.0064345         0.0
#    2 │ AuPRC     0.258165       0.310262       0.258165          0.0
#    3 │ BEDROC    0.036735       0.055047       0.036735          0.0
#    4 │ r20       0.0494968      0.0548745      0.0494968         0.0
#    5 │ p20       0.062603       0.0642504      0.062603          0.0
#    6 │ f1        0.294598       0.301679       0.294598          0.0
#    7 │ bacc     -0.000959355    0.0116378     -0.000959355       0.0
#    8 │ acc       1.58219e-5     0.000100205    1.58219e-5        0.0
#    9 │ mcc     NaN            NaN            NaN               NaN)

# %%
function rescore(df::DataFrame, fx::Function, benchmark::String="0.2")
    uniq = df[:, :Alpha]
    tcols = size(unique(uniq))[1] + ncol(df) - 3
    df_2 = @chain df begin
        groupby([:Fold, :Ligando, :Target, :TP, :Alpha])    
        combine(:Score => sum => :Score)
        unstack(:Alpha, :Score)
        DataFrames.transform(AsTable(5:tcols) .=> ByRow.(fx) .=> [String(Symbol(fx))])
        select(1:4, [benchmark, String(Symbol(fx))])
    end
    return df_2
end


function rescore(df::DataFrame, fxs::Vector{Function}, benchmark::String="0.2")
    symbs = []
    
    uniq = df[:, :Alpha]
    tcols = size(unique(uniq))[1] + ncol(df) - 3
    
    for f in fxs
        push!(symbs, String(Symbol(f)))
    end
    df_2 = @chain df begin
        groupby([:Fold, :Ligando, :Target, :TP, :Alpha])    
        combine(:Score => sum => :Score)
        unstack(:Alpha, :Score)
        DataFrames.transform(AsTable(5:tcols) .=> ByRow.(fxs) .=> symbs)
        select(1:4, [benchmark], symbs)
    end
    return df_2
end


function evaluate(df::DataFrame, fxs::Vector{Function}, benchmark::String="0.2")
    df_f = DataFrame()
    
    symbs = []
    for f in fxs
        push!(symbs, String(Symbol(f)))
    end
    push!(symbs, benchmark)
    
    for metric in symbs
        df_t = @chain df begin
            select(["Fold", "Ligando", "Target", "TP" , metric])
            rename!(5 => :Score)
        end
        
        df_m = getperformance(df_t)
        df_m.groupid = replace(df_m.groupid, missing => metric)
        append!(df_f, df_m)
    end
    
    return df_f
end


function plotmetrics(df::DataFrame, benchmark::String="0.2")
    gr()
        
    df_plot = @chain df begin
        stack(names(df[:, 2:end]), :groupid)
    unstack(:groupid, :value)
    rename!(:variable => :metric)
    end
    
    df_perct = copy(df_plot)
    for n in 2:ncol(df_perct)
    df_perct[:, n] .= (df_plot[:, n] .- df_plot[:,benchmark]) ./ df_plot[:,benchmark]
    end
    
    plot1 = @df df_plot groupedbar(
    :metric,
    cols(2:5),
    bar_width=0.7,
    framestyle = :box,
    lw = 0,
    guidefontsize = 8,
    )
    
    plot2 = @df df_perct groupedbar(
    :metric,
    cols(2:5),
    bar_width=0.7,
    framestyle = :box,
    lw = 0,
    guidefontsize = 8,
    )
    
    display(plot1)
    display(plot2)
    
    return df_plot, df_perct
end
# Out:
# plotmetrics (generic function with 2 methods)

# %%
function allmetrics(df::DataFrame, fxs::Vector{Function}, benchmark::String="0.2")
    df1 = rescore(df, fxs, benchmark)
    df2 = evaluate(df1, fxs, benchmark)
    plotmetrics(df2, benchmark)
end
# Out:
# allmetrics (generic function with 2 methods)

# %%
fxs = [mean, maximum, sum, median]
allmetrics(df, fxs)
# Out:
# (9×6 DataFrame
#  Row │ metric  mean         maximum      sum          median       0.2         ⋯
#      │ String  Float64?     Float64?     Float64?     Float64?     Float64?    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ AuROC     0.788326     0.794083     0.788326     0.573732     0.783286  ⋯
#    2 │ AuPRC     0.176055     0.183345     0.176055     0.159146     0.13993
#    3 │ BEDROC    0.491086     0.49976      0.491086     0.189032     0.473685
#    4 │ r20       0.542592     0.545372     0.542592     0.208564     0.517002
#    5 │ p20       0.0667702    0.0668737    0.0667702    0.0224638    0.0628364 ⋯
#    6 │ f1        0.297174     0.298799     0.297174     0.184156     0.229549
#    7 │ bacc      0.750061     0.759519     0.750061     0.573694     0.750781
#    8 │ acc       0.993862     0.993946     0.993862     0.99382      0.993846
#    9 │ mcc     NaN          NaN          NaN          NaN          NaN         ⋯, 9×6 DataFrame
#  Row │ metric  mean           maximum        sum            median        0.2  ⋯
#      │ String  Float64?       Float64?       Float64?       Float64?      Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ AuROC     0.0064345      0.0137839      0.0064345     -0.267533         ⋯
#    2 │ AuPRC     0.258165       0.310262       0.258165       0.137325
#    3 │ BEDROC    0.036735       0.055047       0.036735      -0.600932
#    4 │ r20       0.0494968      0.0548745      0.0494968     -0.596588
#    5 │ p20       0.062603       0.0642504      0.062603      -0.642504         ⋯
#    6 │ f1        0.294598       0.301679       0.294598      -0.197748
#    7 │ bacc     -0.000959355    0.0116378     -0.000959355   -0.235871
#    8 │ acc       1.58219e-5     0.000100205    1.58219e-5    -2.63698e-5
#    9 │ mcc     NaN            NaN            NaN            NaN              N ⋯
#                                                                 1 column omitted)

# %%
rescore(df, median)
# Out:
# 190785×6 DataFrame
#     Row │ Fold   Ligando      Target          TP       0.2         median
#         │ Int64  String15     String15        Float64  Float64?    Float64
# ────────┼──────────────────────────────────────────────────────────────────
#       1 │     1   CHEMBL1062   CHEMBL1075132      0.0  0.0             0.0
#       2 │     1   CHEMBL1062   CHEMBL1075145      0.0  0.0             0.0
#       3 │     1   CHEMBL1062   CHEMBL1075165      0.0  0.0             0.0
#       4 │     1   CHEMBL1062   CHEMBL1075323      0.0  0.0             0.0
#       5 │     1   CHEMBL1062   CHEMBL1163125      0.0  0.0             0.0
#       6 │     1   CHEMBL1062   CHEMBL1250378      0.0  0.0             0.0
#       7 │     1   CHEMBL1062   CHEMBL1293224      0.0  0.0             0.0
#       8 │     1   CHEMBL1062   CHEMBL1293226      0.0  0.0             0.0
#       9 │     1   CHEMBL1062   CHEMBL1293267      0.0  0.0             0.0
#      10 │     1   CHEMBL1062   CHEMBL1293289      0.0  0.0             0.0
#      11 │     1   CHEMBL1062   CHEMBL1743126      0.0  0.00195495      0.0
#    ⋮    │   ⋮         ⋮             ⋮            ⋮         ⋮          ⋮
#  190776 │   483   CHEMBL99     CHEMBL5838         0.0  0.0             0.0
#  190777 │   483   CHEMBL99     CHEMBL5843         0.0  0.0             0.0
#  190778 │   483   CHEMBL99     CHEMBL5936         0.0  0.0             0.0
#  190779 │   483   CHEMBL99     CHEMBL5971         0.0  0.0             0.0
#  190780 │   483   CHEMBL99     CHEMBL5983         0.0  2.50376e-5      0.0
#  190781 │   483   CHEMBL99     CHEMBL6002         0.0  0.0             0.0
#  190782 │   483   CHEMBL99     CHEMBL6113         0.0  0.0             0.0
#  190783 │   483   CHEMBL99     CHEMBL6154         0.0  0.0             0.0
#  190784 │   483   CHEMBL99     CHEMBL6164         0.0  0.0             0.0
#  190785 │   483   CHEMBL99     CHEMBL6174         0.0  0.0             0.0
#                                                         190764 rows omitted
