# %%
using DataFrames
using CSV
using Glob
using Chain
using Statistics
using SimSpread
using ArgParse
using Base.Threads
using MLBase
using ProgressMeter
using AlgebraOfGraphics
using CairoMakie
using Plots
using StatsPlots
include("getmetrics.jl")
# Out:
# ┌ Warning: The NVIDIA driver on this system only supports up to CUDA 11.0.0.
# │ For performance reasons, it is recommended to upgrade to a driver that supports CUDA 11.2 or higher.
# └ @ CUDA ~/.julia/packages/CUDA/is36v/src/initialization.jl:70
# ["/CLUSTERFS/homes/fnmelo/.local/share/jupyter/runtime/kernel-31d581b1-0651-4362-84f5-83bc8383825f.json"]
# LoadError: ArgParseError("too many arguments")
# in expression starting at /CLUSTERFS/homes/fnmelo/Bioinf_2/getmetrics.jl:200
#
# Stacktrace:
#   [1] argparse_error(x::Any)
#     @ ArgParse ~/.julia/packages/ArgParse/bylyV/src/parsing.jl:9
#   [2] parse_arg!(state::ArgParse.ParserState, settings::ArgParseSettings)
#     @ ArgParse ~/.julia/packages/ArgParse/bylyV/src/parsing.jl:918
#   [3] parse_args_unhandled(args_list::Vector, settings::ArgParseSettings, truncated_shopts::Bool)
#     @ ArgParse ~/.julia/packages/ArgParse/bylyV/src/parsing.jl:632
#   [4] parse_args_unhandled(args_list::Vector, settings::ArgParseSettings)
# ...

# %%
path = "/CLUSTERFS/homes/fnmelo/Bioinf_2"
files = glob("*.out", path)
df = DataFrame()


for file in files
    # extract
    α = @chain file begin
        basename
        replace(".out" => "")
        split('.')
        last
        split('_')
        last
    end
    
    α_value = if startswith(α, "00")
              parse(Float64, α, ) / 100
          else
              parse(Float64, α) / 10
          end
 
    
    # file to df
    file_df = CSV.File(file, delim=",", header=["Fold", "Ligando", "Target", "Score", "TP"]) |> DataFrame
    
    # add alpha 
    file_df[!, "Alpha"] .= α_value
    
    append!(df, file_df)
end

# %%
df_2 = df
df_2 = @chain df_2 begin
    groupby([:Fold, :Ligando, :Target, :TP, :Alpha])    
    combine(:Score => sum => :Score)
    unstack(:Alpha, :Score)
    DataFrames.transform(AsTable(5:24) .=>
              ByRow.([mean, maximum, sum]) .=>
              [:Mean, :Max, :Sum])
    select([1,2,3,4,9,26,27,28])
end
# Out:
# 190785×8 DataFrame
#     Row │ Fold   Ligando      Target          TP       0.2         Mean        ⋯
#         │ Int64  String15     String15        Float64  Float64?    Float64?    ⋯
# ────────┼───────────────────────────────────────────────────────────────────────
#       1 │     1   CHEMBL1062   CHEMBL1075132      0.0  0.0         4.94711e-6  ⋯
#       2 │     1   CHEMBL1062   CHEMBL1075145      0.0  0.0         6.18897e-7
#       3 │     1   CHEMBL1062   CHEMBL1075165      0.0  0.0         2.61921e-6
#       4 │     1   CHEMBL1062   CHEMBL1075323      0.0  0.0         1.30208e-6
#       5 │     1   CHEMBL1062   CHEMBL1163125      0.0  0.0         5.68893e-6  ⋯
#       6 │     1   CHEMBL1062   CHEMBL1250378      0.0  0.0         3.44353e-6
#       7 │     1   CHEMBL1062   CHEMBL1293224      0.0  0.0         2.32767e-6
#       8 │     1   CHEMBL1062   CHEMBL1293226      0.0  0.0         6.49063e-6
#       9 │     1   CHEMBL1062   CHEMBL1293267      0.0  0.0         4.11327e-6  ⋯
# ...

# %%
df = DataFrame()
metric_name = ["0.2", "Mean", "Max", "Sum"]
for names in metric_name
    df_t = @chain df_2 begin
        select(["Fold", "Ligando", "Target", "TP" , names])
        rename!(5 => :Score)
    end
    
    df_m = getperformance(df_t)
    df_m.groupid = replace(df_m.groupid, missing => names)
    
    
    append!(df, df_m)
end

df
# Out:
# 4×10 DataFrame
#  Row │ groupid  AuROC     AuPRC     BEDROC    r20       p20        f1        b ⋯
#      │ String   Float64   Float64   Float64   Float64   Float64    Float64   F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 0.2      0.783286  0.13993   0.473685  0.517002  0.0628364  0.229549  0 ⋯
#    2 │ Mean     0.788326  0.176055  0.491086  0.542592  0.0667702  0.297174  0
#    3 │ Max      0.794083  0.183345  0.49976   0.545372  0.0668737  0.298799  0
#    4 │ Sum      0.788326  0.176055  0.491086  0.542592  0.0667702  0.297174  0
#                                                                3 columns omitted

# %%
using Plots
using StatsPlots
gr()
@df df groupedbar(
    # :groupid,   
    cols(2:9),
    bar_position = :dodge,
    orientation = :horizontal,
    bar_width=0.7,
    framestyle = :box,
    lw = 0,
    # group=:groupid
    # label=["AuROC" "AuPRC" "BEDROC" "r20" "p20" "f1" "acc"]
    
)

# %%
df_plot = @chain df begin
    stack([:p20, :r20, :bacc, :acc, :mcc, :f1, :BEDROC, :AuPRC, :AuROC], :groupid)
    unstack(:groupid, :value)
    rename!(:variable => :metric)
end


@df df_plot groupedbar(
    :metric,
    cols(2:5),
    # bar_position = :dodge,
    # orientation = :horizontal,
    permute = (:x, :y),
    bar_width=0.7,
    framestyle = :box,
    lw = 0,
    # guide = :metric,
    # xlabel = "Performance",
    guidefontsize = 8,
    # aspect_ratio=:equal
    # ylims = (0,1),
  
    
    # group=:metric
    # ylabel=["AuROC", "AuPRC", "BEDROC", "r20", "p20", "f1" ,"acc"]
    )

# %%
@df df_plot groupedbar(
    :metric,
    cols(2:5),
    # bar_position = :dodge,
    # orientation = :horizontal,
    # permute = (:x, :y),
    bar_width=0.7,
    framestyle = :box,
    lw = 0,
    # guide = :metric,
    # xlabel = "Performance",
    guidefontsize = 8,
    # aspect_ratio=:equal
    # ylims = (0,1),
  
    
    # group=:metric
    # ylabel=["AuROC", "AuPRC", "BEDROC", "r20", "p20", "f1" ,"acc"]
    )

# %%
df_perct = copy(df_plot)
for n in 2:5
    df_perct[:, n] .= (df_plot[:, n] .- df_plot[:,2]) ./ df_plot[:,2]
end
df_perct
# Out:
# 9×5 DataFrame
#  Row │ metric  0.2       Mean           Max            Sum
#      │ String  Float64?  Float64?       Float64?       Float64?
# ─────┼───────────────────────────────────────────────────────────────
#    1 │ p20          0.0    0.062603       0.0642504      0.062603
#    2 │ r20          0.0    0.0494968      0.0548745      0.0494968
#    3 │ bacc         0.0   -0.000959355    0.0116378     -0.000959355
#    4 │ acc          0.0    1.58219e-5     0.000100205    1.58219e-5
#    5 │ mcc        NaN    NaN            NaN            NaN
#    6 │ f1           0.0    0.294598       0.301679       0.294598
#    7 │ BEDROC       0.0    0.036735       0.055047       0.036735
#    8 │ AuPRC        0.0    0.258165       0.310262       0.258165
#    9 │ AuROC        0.0    0.0064345      0.0137839      0.0064345

# %%
@df df_perct groupedbar(
    :metric,
    cols(2:5),
    # bar_position = :dodge,
    # orientation = :horizontal,
    # permute = (:x, :y),
    bar_width=0.7,
    framestyle = :box,
    lw = 0,
    # guide = :metric,
    # xlabel = "Performance",
    guidefontsize = 8,
    # aspect_ratio=:equal
    # ylims = (0,1),
  
    
    # group=:metric
    # ylabel=["AuROC", "AuPRC", "BEDROC", "r20", "p20", "f1" ,"acc"]
    )
